# %%
import automate as aml

# %%
aml.autoML_run('datasets/heart_failure.csv','DEATH_EVENT','heart_failure')
# Out:
# Preprocessing
#
# Modeling with field specifications:
# age: numeric
# anaemia: categorical
# creatinine_phosphokinase: numeric
# diabetes: categorical
# ejection_fraction: numeric
# high_blood_pressure: categorical
# platelets: numeric
# serum_creatinine: numeric
# serum_sodium: numeric
# sex: categorical
# smoking: categorical
# time: numeric
# DEATH_EVENT: categorical
#
#
# column name changes
# age: age
# anaemia: anaemia
# creatinine_phosphokinase: creatinine_phosphokinase
# diabetes: diabetes
# ejection_fraction: ejection_fraction
# high_blood_pressure: high_blood_pressure
# platelets: platelets
# serum_creatinine: serum_creatinine
# serum_sodium: serum_sodium
# sex: sex
# smoking: smoking
# time: time
# DEATH_EVENT: death_event
#
#
#
# Problem Type:  classification
# No null values found
# Outliers Count :  76
# No features reduced in PCA
#
# Modelling
#
# Logistic Regression
#
# Best penalty = l2
# Best C = 4832.930238571752
# Best l1_ratio = 0.05263157894736842
# ...

# %%
aml.autoML_run('datasets/insurance.csv','charges','insurance')
# Out:
# Preprocessing
#
# Modeling with field specifications:
# age: numeric
# sex: categorical
# bmi: numeric
# children: categorical
# smoker: categorical
# region: categorical
# charges: numeric
#
#
# column name changes
# age: age
# sex: sex
# bmi: bmi
# children: children
# smoker: smoker
# region: region
# charges: charges
#
#
#
# Problem Type:  regression
# No null values found
# Outliers Count :  9
# No features reduced in PCA
#
# Modelling
#
# Linear Regression
#
# 	Mean Square Error = 120902565.85085402
# 	Mean Absolute Erroe = 8612.536636404902
# 	Coefficient Of Determination  = -6.658665713028531
#
# 	Mean Square Error = 102565750.45163523
# 	Mean Absolute Erroe = 8155.282812539572
# 	Coefficient Of Determination  = -5.248742480577945
#
# 	Mean Square Error = 124059993.96254179
# 	Mean Absolute Erroe = 8759.616309587836
# 	Coefficient Of Determination  = -7.07378941196993
#
# 	Mean Square Error = 109198090.91042036
# 	Mean Absolute Erroe = 8460.882755578858
# ...

# %%
aml.autoML_run('datasets/housing.csv','MEDV','housing')
# Out:
# Preprocessing
#
# Modeling with field specifications:
# RM: numeric
# LSTAT: numeric
# PTRATIO: numeric
# MEDV: numeric
#
#
# column name changes
# RM: rm
# LSTAT: lstat
# PTRATIO: ptratio
# MEDV: medv
#
#
#
# Problem Type:  regression
# No null values found
# Outliers Count :  38
# No features reduced in PCA
#
# Modelling
#
# Linear Regression
#
# 	Mean Square Error = 7567835614.865011
# 	Mean Absolute Erroe = 64588.08877019977
# 	Coefficient Of Determination  = 0.3951165040735527
#
# 	Mean Square Error = 3990427449.8392925
# 	Mean Absolute Erroe = 50069.83045498056
# 	Coefficient Of Determination  = 0.7756264531600002
#
# 	Mean Square Error = 7758690440.091637
# 	Mean Absolute Erroe = 66726.7042925263
# 	Coefficient Of Determination  = 0.19577338822013135
#
# 	Mean Square Error = 7966009707.194095
# 	Mean Absolute Erroe = 70957.06075644483
# 	Coefficient Of Determination  = 0.3431350154101046
#
# 	Mean Square Error = 3729809375.1772494
# 	Mean Absolute Erroe = 48561.79917865699
# ...

# %%
aml.autoML_run('datasets/breast_cancer.csv','diagnosis','breast_cancer')
# Out:
# Preprocessing
#
# Modeling with field specifications:
# mean_radius: numeric
# mean_texture: numeric
# mean_perimeter: numeric
# mean_area: numeric
# mean_smoothness: numeric
# diagnosis: categorical
#
#
# column name changes
# mean_radius: mean_radius
# mean_texture: mean_texture
# mean_perimeter: mean_perimeter
# mean_area: mean_area
# mean_smoothness: mean_smoothness
# diagnosis: diagnosis
#
#
#
# Problem Type:  classification
# No null values found
# Outliers Count :  36
# No features reduced in PCA
#
# Modelling
#
# Logistic Regression
#
# Best penalty = none
# Best C = 100000.0
# Best l1_ratio = 0.9473684210526315
# 	Confusion Matrix
# 	 [17  1]
# 	 [ 2 34]
# 	Accuracy = 0.9444444444444444
# 	Recall [Neg Pos] = 0.9444444444444444
# 	Precision [Neg Pos] = 0.9458646616541352
# 	F1 score [Neg Pos]  = 0.944803958888466
# 	AUC = 0.5593984962406016
#
# 	Confusion Matrix
# 	 [16  2]
# 	 [ 2 34]
# 	Accuracy = 0.9259259259259259
# 	Recall [Neg Pos] = 0.9259259259259259
# ...
